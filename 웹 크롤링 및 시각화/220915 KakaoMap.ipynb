# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd #엑셀화 판다스
import time
from selenium.webdriver.common.keys import Keys #키보드
from bs4 import BeautifulSoup as bs

# %%
# 창 열기
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://map.kakao.com/")

# 원 지우기
circle = driver.find_element_by_css_selector('body > div.coach_layer.coach_layer_type1 > div > div > div > span')
circle.click()

# "원하는 위치" 검색어 입력
search = driver.find_element_by_css_selector("#search\.keyword\.query")
search.send_keys("총신대입구역 맛집")

# 검색버튼 누르기
sr_click = driver.find_element_by_css_selector('#search\.keyword\.submit')
sr_click.click()
driver.implicitly_wait(5)

# #입력한 검색어 지우기
# search.clear()

# 검색한 부분에서 활동할 수 있도록 클릭
result = driver.find_element_by_css_selector("#info\.search\.place > div.sectiontitle > h5")
result.click()

# 검색한 부분에서 활동할 수 있도록 클릭
more = driver.find_element_by_css_selector("#info\.search\.place\.more")
more.click()
time.sleep(2)

name_list = []
custom_num_list = []
site_list = []

# 페이지 넘기기 : while
for i in range(2):
    for i in range(1, 6):
        try:
            # 아이템 페이지 마다 i가 달라짐
            page = driver.find_element_by_xpath(f'//*[@id="info.search.page.no{i}"]')
            page.click()
            time.sleep(1)
    
            # 이동한 페이지에서 원하는 정보 가져오는 seletor 선언하기
            name = driver.find_elements_by_css_selector('strong > a.link_name')
            custom_num = driver.find_elements_by_css_selector('span.score > em')
            site = driver.find_elements_by_css_selector('div.addr > p:nth-child(1)')

            # 원하는 정보 리스트에 넣기
            for x in name:
                name_list.append(x.text)
            for x in custom_num:
                custom_num_list.append(x.text)
            for x in site:
                site_list.append(x.text)

        except:
            print(f"{i}번째 오류~!")
            break

    # 6으로 넘어가기 위한 더보기(>) 누르기
    page_more = driver.find_element_by_css_selector('#info\.search\.page\.next')
    page_more.click()

driver.close()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In [2], line 2
#       1 # 창 열기
# ----> 2 driver = webdriver.Chrome(ChromeDriverManager().install())
#       3 driver.get("https://map.kakao.com/")
#       5 # 원 지우기
#
# File c:\Users\user\anaconda3_\lib\site-packages\selenium\webdriver\chrome\webdriver.py:76, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      73 self.service.start()
#      75 try:
# ---> 76     RemoteWebDriver.__init__(
#      77         self,
#      78         command_executor=ChromeRemoteConnection(
#      79             remote_server_addr=self.service.service_url,
#      80             keep_alive=keep_alive),
#      81         desired_capabilities=desired_capabilities)
#      82 except Exception:
#      83     self.quit()
#
# File c:\Users\user\anaconda3_\lib\site-packages\selenium\webdriver\remote\webdriver.py:157, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     154 if browser_profile is not None:
#     155     warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                   DeprecationWarning, stacklevel=2)
# --> 157 self.start_session(capabilities, browser_profile)
#     158 self._switch_to = SwitchTo(self)
#     159 self._mobile = Mobile(self)
#
# File c:\Users\user\anaconda3_\lib\site-packages\selenium\webdriver\remote\webdriver.py:252, in WebDriver.start_session(self, capabilities, browser_profile)
#     249 w3c_caps = _make_w3c_caps(capabilities)
#     250 parameters = {"capabilities": w3c_caps,
#     251               "desiredCapabilities": capabilities}
# --> 252 response = self.execute(Command.NEW_SESSION, parameters)
#     253 if 'sessionId' not in response:
#     254     response = response['value']
#
# File c:\Users\user\anaconda3_\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\user\anaconda3_\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 106
# Current browser version is 105.0.5195.127 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe

# %%
print(len(name_list), "\n\n", len(custom_num_list), "\n\n", len(site_list))
# Out:
# 150
#
#  150
#
#  150

# %%
num = list(range(1,len(name_list)+1))
 
data = {"상호명" : name_list, "별점" : custom_num_list, "주소" : site_list}
 
restaurante = pd.DataFrame(data)
restaurante.sort_values(by = ["별점"], ascending = False, inplace=True)
restaurante.insert(0, "순위", num)
restaurante.set_index("순위", inplace=True)
# restaurant.set_index("순위", inplace=True) #inplace : 원본대체
# restaurant.reindex(index=num) #index를 새로 지정
# restaurant = restaurant.reset_index(drop=True)
restaurante
# Out:
#               상호명   별점                     주소
# 순위
# 1        용용선생 이수점  4.7  서울 동작구 동작대로27다길 26 1층
# 2          바른황소곱창  4.6     서울 동작구 동작대로7길 4 1층
# 3        강고집 사당본점  4.6    서울 서초구 방배천로4안길 6 1층
# 4            디피스트  4.6   서울 동작구 동작대로27길 31 2층
# 5         소백양훠궈샤브  4.6    서울 동작구 동작대로29길 8 2층
# ..            ...  ...                    ...
# 146  도어이스케이프 이수역점  0.0  서울 동작구 동작대로27가길 14 3층
# 147          정애맛담       서울 동작구 동작대로29나길 10 1층
# 148      도너츠윤 방배점        서울 서초구 동광로12가길 12 1층
# 149        낯선한식븟다         서울 동작구 사당로30길 28 1층
# 150          호시라멘        서울 서초구 방배천로2안길 39 1층
#
# [150 rows x 3 columns]

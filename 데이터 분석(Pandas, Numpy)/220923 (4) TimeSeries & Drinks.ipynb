# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import  font_manager, rc

# %% [markdown]
# ### Time Series

# %% [markdown]
# pd.date_range("시작일", "마직막일")
# 시작일부터 마지막날짜까지 데이터화 함

# %%
dates = pd.date_range("2016-05-01", "2016-05-07")
dates
# Out:
# DatetimeIndex(['2016-05-01', '2016-05-02', '2016-05-03', '2016-05-04',
#                '2016-05-05', '2016-05-06', '2016-05-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
tmp1 = pd.Series([80, 92, 82, 97, 84, 78, 98], index = dates, name = "수학")
tmp1
# Out:
# 2016-05-01    80
# 2016-05-02    92
# 2016-05-03    82
# 2016-05-04    97
# 2016-05-05    84
# 2016-05-06    78
# 2016-05-07    98
# Freq: D, Name: 수학, dtype: int64

# %%
tmp2 = pd.Series(np.random.randint(0, 100, 7), index = dates, name="철학")
# tmp2 = np.random.randint(0, 100, 7)
tmp2
# Out:
# 2016-05-01    75
# 2016-05-02    38
# 2016-05-03     5
# 2016-05-04    72
# 2016-05-05    84
# 2016-05-06    42
# 2016-05-07    60
# Freq: D, Name: 철학, dtype: int32

# %%
ex = pd.concat([tmp1, tmp2], axis=1)
ex

#2016년 5월 5일 점수
ex.loc["2016-05-05"]

#5/4, 5/6, 5/7의 철학점수만
ex.loc["2016-05-04" : "2016-05-07"]["철학"]
# ex.loc["2016-05-04" : ]["철학"]
# ex["철학"][3:7]
# Out:
# 2016-05-04    72
# 2016-05-05    84
# 2016-05-06    42
# 2016-05-07    60
# Freq: D, Name: 철학, dtype: int32

# %%
#drop으로 원하는 데이터만 남기기
#t = ex는 ex도 바뀜
t = ex.copy()
t.drop(columns="수학", index=t.index[0:3], inplace=True)
t

# 수학점수와 철학점수 차 구해서 열 추가하기
ex["점수 차"] = ex.수학 - ex.철학
ex
# Out:
#             수학  철학  점수 차
# 2016-05-01  80  75     5
# 2016-05-02  92  38    54
# 2016-05-03  82   5    77
# 2016-05-04  97  72    25
# 2016-05-05  84  84     0
# 2016-05-06  78  42    36
# 2016-05-07  98  60    38

# %%
#컬럼이름 바꾸기
ex.rename(inplace=True 
          , columns={"수학" : "Math", "철학" : "philosopy", "점수 차":"diff"}
          )
ex.drop(columns="diff", inplace=True)
ex
# Out:
#             Math  philosopy
# 2016-05-01    80         75
# 2016-05-02    92         38
# 2016-05-03    82          5
# 2016-05-04    97         72
# 2016-05-05    84         84
# 2016-05-06    78         42
# 2016-05-07    98         60

# %%
# and,or 중 하나 사용해서
# 5-3, 5-4의 시험점수를 DF형태로 가져오기

ex.iloc[2:4]
ex[(ex.index == "2016-05-03") | (ex.index == "2016-05-04")]
# Out:
#             Math  philosopy
# 2016-05-03    82          5
# 2016-05-04    97         72

# %%
#수학점수가 85이상이 5-1~5-5사이

#point : 날짜도 부등호로 사용가능

ex[(ex.Math >= 85) & ((ex.index >= "2016-05-01") & (ex.index <= "2016-05-05"))]
# Out:
#             Math  philosopy
# 2016-05-02    92         38
# 2016-05-04    97         72

# %%
# %matplotlib inline
#소리나, 영상, 이미지를 선명하게 가져옴

# ex.plot()
ex.plot(kind = "bar"
        , figsize = (15,5)
        , title = "Score"
        )
# plt.xlabel("date")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %%
#IMOB영화리뷰 데이터셋을 인터넷에서 불러오기
movie = pd.read_csv("http://bit.ly/imdbratings"
                    , encoding = "EUC-KR"
                    , index_col = "title"
                    )
movie.head(5)
# movie.shape
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# Out:
#                                                star_rating content_rating  \
# title
# The Godfather: Part II                                 9.1              R
# The Lord of the Rings: The Return of the King          8.9          PG-13
# Seven Samurai                                          8.7        UNRATED
# Once Upon a Time in America                            8.4              R
# Lawrence of Arabia                                     8.4             PG
# Lagaan: Once Upon a Time in India                      8.3             PG
# Gone with the Wind                                     8.2              G
# Ben-Hur                                                8.1              G
# The Ten Commandments                                   7.9       APPROVED
# Hamlet                                                 7.8          PG-13
# Malcolm X                                              7.7          PG-13
# It's a Mad, Mad, Mad, Mad World                        7.6       APPROVED
#
#                                                    genre  duration  \
# title
# The Godfather: Part II                             Crime       200
# The Lord of the Rings: The Return of the King  Adventure       201
# Seven Samurai                                      Drama       207
# Once Upon a Time in America                        Crime       229
# Lawrence of Arabia                             Adventure       216
# Lagaan: Once Upon a Time in India              Adventure       224
# Gone with the Wind                                 Drama       238
# Ben-Hur                                        Adventure       212
# The Ten Commandments                           Adventure       220
# Hamlet                                             Drama       242
# Malcolm X                                      Biography       202
# It's a Mad, Mad, Mad, Mad World                   Action       205
#
#                                                                                      actors_list
# title
# The Godfather: Part II                         [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Lord of the Rings: The Return of the King  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# Seven Samurai                                  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# Once Upon a Time in America                    [u'Robert De Niro', u'James Woods', u'Elizabet...
# Lawrence of Arabia                             [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# Lagaan: Once Upon a Time in India              [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# Gone with the Wind                             [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# Ben-Hur                                        [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# The Ten Commandments                           [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# Hamlet                                         [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# Malcolm X                                      [u'Denzel Washington', u'Angela Bassett', u'De...
# It's a Mad, Mad, Mad, Mad World                [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %%
booleans = []
for length in movie.duration:
    if length >= 200:
        booleans.append(True)
    else:
        booleans.append(False)
up_200 = movie[booleans]        
movie[booleans] == movie[movie.duration >= 200]
# movie[booleans]
# Out:
#                                                star_rating  content_rating  \
# title
# The Godfather: Part II                                True            True
# The Lord of the Rings: The Return of the King         True            True
# Seven Samurai                                         True            True
# Once Upon a Time in America                           True            True
# Lawrence of Arabia                                    True            True
# Lagaan: Once Upon a Time in India                     True            True
# Gone with the Wind                                    True            True
# Ben-Hur                                               True            True
# The Ten Commandments                                  True            True
# Hamlet                                                True            True
# Malcolm X                                             True            True
# It's a Mad, Mad, Mad, Mad World                       True            True
#
#                                                genre  duration  actors_list
# title
# The Godfather: Part II                          True      True         True
# The Lord of the Rings: The Return of the King   True      True         True
# Seven Samurai                                   True      True         True
# Once Upon a Time in America                     True      True         True
# Lawrence of Arabia                              True      True         True
# Lagaan: Once Upon a Time in India               True      True         True
# Gone with the Wind                              True      True         True
# Ben-Hur                                         True      True         True
# The Ten Commandments                            True      True         True
# Hamlet                                          True      True         True
# Malcolm X                                       True      True         True
# It's a Mad, Mad, Mad, Mad World                 True      True         True

# %%
# 이번 장르가 Crime또는 Drama 또는 Action인 영화리스트
# condition = ((movie.genre))
condition = movie.genre.isin(["Crime", "Drama", "Action"])
movie[condition]

# condition2 = movie.genre.str.contains(["Crime", "Drama", "Action"])
# condition2 = movie.genre.str.contains("Crime", "Drama", "Action")
# condition2
# movie[condition2]
movie.genre
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 나라별 음주현황

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry'
                     , index_col = "country")
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
new = pd.Series([drinks.beer_servings.sum(), drinks.spirit_servings.sum(),drinks.wine_servings.sum()]
                , index = ["beer_servings", "spirit_servings", "wine_servings"]
                , name = "전 세계 알콜별 소비량"
                )

# =================================== 그래프 그리기====================================
font_name = font_manager.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
rc("font", family = font_name)

explode = [0.03, 0.03, 0.03]
colors = ['#4F6272', '#B7C3F3', '#DD7596']

plt.figure(figsize = (5,5)).patch.set_facecolor("w")
plt.pie(
        #넣고 싶은 데이터
            new  
        #레이블 설정
            , labels = ["beer_servings", "spirit_servings", "wine_servings"] #각 그래프에 파이부분
            , labeldistance=1.1  #레이블이 그래프레어 얼마나 멀리 위치하냐(기본은 1.1정도)
            , counterclock=True #counterclock = False는 반시계방향
        #그래프 안에 내용 설정
            , autopct="%1.2f%%"  #소수점 1번째까지 실수로 표현해줘
            , colors=colors #그래프안 색 변경
        #그래프 설정
            , explode=explode #중심에서 벗어나기
            , wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }
            , shadow = True #음영넣기
        ) 

plt.title("전 세계 주류 종류별 소비량")

plt.show()

# %%
test_sum = drinks.reset_index().set_index("continent").iloc[:, 1:2].groupby("continent").sum()
test_mean = drinks.reset_index().set_index("continent").iloc[:, 1:2].groupby("continent").mean()
test_max = drinks.reset_index().set_index("continent").iloc[:, 1:2].groupby("continent").max()

#=======================================================================

beer_agg = drinks.groupby("continent").beer_servings.agg(["count", "mean", "min", "max"])
wine_agg = drinks.groupby("continent").wine_servings.agg(["count", "mean", "min", "max"])
spirit_agg = drinks.groupby("continent").spirit_servings.agg(["count", "mean", "min", "max"])

spirit_agg[]
# Out:
#                count        mean  min  max
# continent
# Africa            53   16.339623    0  152
# Asia              44   60.840909    0  326
# Europe            45  132.555556    0  373
# North America     23  165.739130   68  438
# Oceania           16   58.437500    0  254
# South America     12  114.750000   25  302

# %%
plt.plot.barh(test.index, test.values)
plt.xticks(np.arange(0,7000, 500))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import  font_manager, rc
import seaborn as sns #시각화를 쉽게 만들어줌

# font_name = font_manager.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
# rc("font", family = font_name)

from matplotlib.pylab import rcParams

rcParams['font.family']='malgun gothic' #malgun gothic
rcParams['figure.figsize']=17,8
import warnings
warnings.filterwarnings('ignore')

import statsmodels.api as sm

# %%
df = pd.read_csv("Traffic_Accident_2017.csv", encoding = "EUC-KR", index_col="발생년")
df["사망 및 부상자수"] = df.사망자수 + df.사상자수 + df.중상자수 + df.경상자수

# %%
sns.scatterplot(data = df
              , x = "경도"
              , y = "위도"
              , hue = "사고유형_대분류"
              )

plt.show()

# %%
# font_name = font_manager.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
# rc("font", family = font_name)

explode = [0, 0.10, 0, 0.10, 0, 0.10, 0, 0.10]
# colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']

plt.figure(figsize = (5,5)).patch.set_facecolor("w") #그래프 배경색 바꾸기

plt.pie(a.사상자수  #넣고 싶은 데이터
                #레이블 설정
				, labels= a.index #각 그래프에 파이부분
                , labeldistance=1.2  #레이블이 그래프레어 얼마나 멀리 위치하냐(기본은 1.1정도)
				, counterclock=False #counterclock = False는 반시계방향
                #그래프 안에 내용 설정
				, autopct="%1.1f%%"  #소수점 1번째까지 실수로 표현해줘
                # , colors=colors #그래프안 색 변경
                #그래프 설정
                , explode=explode #중심에서 벗어나기
                , wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }
                , shadow = True #음영넣기
                ) 

plt.title("발생지시도별 사망자수")

plt.rcParams["figure.figsize"] = (10,10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 9
#       5 # colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
#       7 plt.figure(figsize = (5,5)).patch.set_facecolor("w") #그래프 배경색 바꾸기
# ----> 9 plt.pie(a.사상자수  #넣고 싶은 데이터
#      10                 #레이블 설정
#      11 				, labels= a.index #각 그래프에 파이부분
#      12                 , labeldistance=1.2  #레이블이 그래프레어 얼마나 멀리 위치하냐(기본은 1.1정도)
#      13 				, counterclock=False #counterclock = False는 반시계방향
#      14                 #그래프 안에 내용 설정
#      15 				, autopct="%1.1f%%"  #소수점 1번째까지 실수로 표현해줘
#      16                 # , colors=colors #그래프안 색 변경
#      17                 #그래프 설정
#      18                 , explode=explode #중심에서 벗어나기
#      19                 , wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }
#      20                 , shadow = True #음영넣기
#      21                 )
# ...

# %%
a = df[["발생지시도", "사상자수"]].set_index("발생지시도")

# %%
a.index
# Out:
# Index(['전남', '서울', '충남', '충남', '서울', '강원', '경기', '광주', '제주', '충남',
#        ...
#        '광주', '경기', '제주', '경북', '대전', '경남', '부산', '강원', '경기', '대전'],
#       dtype='object', name='발생지시도', length=4065)
